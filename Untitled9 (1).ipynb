# %%
import pandas as pd
import seaborn as sns

# %%
sales = pd.read_csv('/content/sales data-set.csv')

# %%
store = pd.read_csv('/content/stores data-set.csv')
feature = pd.read_csv('/content/Features data set.csv')

# %%
# da1 = pd.merge(sales,store,on='Store',how='outer')

# %%
# da1

# %%
feature
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  05/02/2010        42.31       2.572        NaN        NaN
# 1         1  12/02/2010        38.51       2.548        NaN        NaN
# 2         1  19/02/2010        39.93       2.514        NaN        NaN
# 3         1  26/02/2010        46.63       2.561        NaN        NaN
# 4         1  05/03/2010        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  28/06/2013        76.05       3.639    4842.29     975.03
# 8186     45  05/07/2013        77.50       3.614    9090.48    2268.58
# 8187     45  12/07/2013        79.37       3.614    3789.94    1827.31
# 8188     45  19/07/2013        82.84       3.737    2961.49    1047.07
# 8189     45  26/07/2013        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
# all_datas = pd.merge(da1,feature,on='Store',how='outer')

# %%
sales
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  05/02/2010      24924.50      False
# 1           1     1  12/02/2010      46039.49       True
# 2           1     1  19/02/2010      41595.55      False
# 3           1     1  26/02/2010      19403.54      False
# 4           1     1  05/03/2010      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  28/09/2012        508.37      False
# 421566     45    98  05/10/2012        628.10      False
# 421567     45    98  12/10/2012       1061.02      False
# 421568     45    98  19/10/2012        760.01      False
# 421569     45    98  26/10/2012       1076.80      False
#
# [421570 rows x 5 columns]

# %%
sales['IsHoliday'].isnull().values
# Out:
# array([False, False, False, ..., False, False, False])

# %%
sales.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday'], dtype='object')

# %%
sales.describe()
# Out:
#                Store           Dept   Weekly_Sales
# count  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123
# std        12.785297      30.492054   22711.183519
# min         1.000000       1.000000   -4988.940000
# 25%        11.000000      18.000000    2079.650000
# 50%        22.000000      37.000000    7612.030000
# 75%        33.000000      74.000000   20205.852500
# max        45.000000      99.000000  693099.360000

# %%
#Predict the department-wide sales for each store for the following year

# %%
sales.groupby(['Store']).sum()
# Out:
#          Dept  Weekly_Sales  IsHoliday
# Store
# 1      454749  2.224028e+08        723
# 2      455425  2.753824e+08        722
# 3      370825  5.758674e+07        633
# 4      457340  2.995440e+08        727
# 5      371526  4.547569e+07        640
# 6      453812  2.237561e+08        721
# 7      432878  8.159828e+07        691
# 8      432217  1.299512e+08        696
# 9      355292  7.778922e+07        625
# 10     454210  2.716177e+08        724
# 11     448403  1.939628e+08        707
# 12     421799  1.442872e+08        683
# 13     467392  2.865177e+08        739
# 14     442053  2.889999e+08        703
# 15     435886  8.913368e+07        701
# 16     402800  7.425243e+07        673
# 17     429973  1.277821e+08        691
# 18     428796  1.551147e+08        690
# 19     455864  2.066349e+08        715
# 20     450413  3.013978e+08        723
# 21     412056  1.081179e+08        670
# 22     422781  1.470756e+08        680
# 23     441720  1.987506e+08        704
# ...

# %%
import matplotlib.pyplot as plt

# %%
a1 = (sales['IsHoliday'] == False).sum()
a2 = (sales['IsHoliday'] == True).sum()
plt.figure(figsize=(10,5)) 

plt.pie([a1,a2],colors=['lightblue','salmon'],labels=['non-holiday','holiday'],startangle=90,explode=(0.1,0.1),autopct='%1.1f%%')
plt.title('holidays vs non-holidays %')
plt.axis('equal')
plt.show()

# %%
feature
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  05/02/2010        42.31       2.572    4743.58        NaN
# 1         1  12/02/2010        38.51       2.548    4743.58        NaN
# 2         1  19/02/2010        39.93       2.514    4743.58        NaN
# 3         1  26/02/2010        46.63       2.561    4743.58        NaN
# 4         1  05/03/2010        46.50       2.625    4743.58        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  28/06/2013        76.05       3.639    4842.29     975.03
# 8186     45  05/07/2013        77.50       3.614    9090.48    2268.58
# 8187     45  12/07/2013        79.37       3.614    3789.94    1827.31
# 8188     45  19/07/2013        82.84       3.737    2961.49    1047.07
# 8189     45  26/07/2013        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
feature.MarkDown5.std()
# Out:
# 13086.690278200194

# %%
feature.MarkDown5.mean()
# Out:
# 4132.216422222222

# %%
feature.Temperature.mode()
# Out:
# 0    50.43
# 1    70.28
# dtype: float64

# %%
plt.hist(feature.Temperature,color=['salmon'])
plt.title('maxx Temperature')
# plt.xlabel('Temperate')
plt.show()

# %%
gp_fea = feature.groupby(['Store']).sum()
gp_fea.head()
# Out:
#        Temperature  Fuel_Price   MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# Store
# 1         12177.99     593.182  1204702.71  244287.34  148701.02  328826.83
# 2         12144.57     593.182  1372032.42  371466.83  205980.91  395710.14
# 3         12811.74     593.182   726830.93   75718.43   98447.56   67609.03
# 4         11177.83     592.389  1382861.56  376682.61  205728.15  472582.16
# 5         12416.86     593.182   708989.93   78340.07   79954.85   86786.08
#
#        MarkDown5           CPI  Unemployment  IsHoliday
# Store
# 1      398547.69  36718.913780      1257.528         13
# 2      536506.99  36659.250111      1251.269         13
# 3      103801.49  37296.630674      1184.015         13
# 4      555633.69  21834.308451       954.419         13
# 5      198483.79  36815.696249      1041.575         13

# %%
plt.figure(figsize=(20,10))
gp_fea['Temperature'].plot(kind='bar',color=['lightblue'])
plt.title('Temperature in each store')
plt.show()

# %%
feature.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  05/02/2010        42.31       2.572    4743.58        NaN
# 1      1  12/02/2010        38.51       2.548    4743.58        NaN
# 2      1  19/02/2010        39.93       2.514    4743.58        NaN
# 3      1  26/02/2010        46.63       2.561    4743.58        NaN
# 4      1  05/03/2010        46.50       2.625    4743.58        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
feature['Date'] = pd.to_datetime(feature['Date'])

# %%
feature['Date']
# Out:
# 0      2010-05-02
# 1      2010-12-02
# 2      2010-02-19
# 3      2010-02-26
# 4      2010-05-03
#           ...
# 8185   2013-06-28
# 8186   2013-05-07
# 8187   2013-12-07
# 8188   2013-07-19
# 8189   2013-07-26
# Name: Date, Length: 8190, dtype: datetime64[ns]

# %%
plt.figure(figsize=(20,10))

plt.scatter(feature.Fuel_Price[feature.IsHoliday == False],feature.Date[feature.IsHoliday == False])
plt.show()

# %%
store['Store'].plot(kind='bar')

# %%
store.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
mew_col = pd.get_dummies(store['Type'],prefix='type_')

# %%
store = store.join(mew_col)

# %%
store.head()
# Out:
#    Store Type    Size  type__A  type__B  type__C
# 0      1    A  151315        1        0        0
# 1      2    A  202307        1        0        0
# 2      3    B   37392        0        1        0
# 3      4    A  205863        1        0        0
# 4      5    B   34875        0        1        0

# %%
plt.figure(figsize=(20,10))
plt.pie([store.type__A.sum(),store.type__B.sum(),store.type__C.sum()],labels=['A','B','C'],colors=['salmon','grey','lightblue'],explode=(0.05,0.1,0.05),autopct='%1.1f%%',shadow=True)
plt.title('% of types of store')
plt.show()
